# %%
import random
import tweepy

# %%
consumer_key = ""
consumer_secret = ""

# %%
callback_uri = 'oob'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_uri)
redirect_url = auth.get_authorization_url()
print(redirect_url)
# Out:
# https://api.twitter.com/oauth/authorize?oauth_token=sCKpDQAAAAABMgMvAAABd3xnmY8

# %%
user_pint_input = input("What's the pin value? ")
# Out:
# What's the pin value? 8372792

# %%
user_pint_input
# Out:
# '8372792'

# %%
auth.get_access_token(user_pint_input)
# Out:
# ('',
#  '')

# %%
api = tweepy.API(auth)

# %%
me = api.me()

# %%
print(me.screen_name)
# Out:
# CryptoAdvisor14

# %%
Moneda = "aaaaaaaaaaaaaaa"
positiu = "nanan"
import nltk
import pickle
import pandas as pd

def postt(Moned, positiv) :
    if Moned != "nada tete":
        print ("amo a publika")
        numerolio = random.randint(0, 999999)
        if positiv == 1:
            print ("amo a publika positivo")
            api.update_status(f"There is a famous person talking good about {Moned}{numerolio}" )
        elif positiv == 0:
            print ("amo a publika negativo")
            api.update_status(f"There is a famous person talking shit about {Moned}{numerolio}") 
        Moned = "nada tete"
        
f = open('./model_sentiment.pickle', 'rb')
classifier = pickle.load(f)
f.close()

f = open('./dictionary.pickle', 'rb')
vocabulary = pickle.load(f)
f.close()

def extract_features(review):
    review_words=set(review)
    features={}
    for word in vocabulary:
        features[word]=(word in review_words)
    return features
#LECTURA DATASET DE CRIPTOS###############################################
data=pd.read_csv('data_bitcoins.csv',index_col=0)
x=data.to_dict()
lista=list(x.values())
cryptos=lista[0]
######################################################################

cryptos_list1 = []
abreujaments_incomplerts = list(cryptos.keys())

abreujaments = ["$" + suit for suit in abreujaments_incomplerts]

cryptos_list1 = list(cryptos.values()) +list(abreujaments)
print ("final:", cryptos_list1)

cryptos_list = cryptos_list1


twit="hjj"
import tweepy

class TweetsListener(tweepy.StreamListener):
    def on_connect(self):
        print("Working")
    
    def on_status(self,status):  #aqui es pot guardar una base de dades de piulades actuals
        print(status.text)
        twit1= status.text
        twit = twit1
        for i in cryptos_list:
            for word in twit.split():
                if i.lower() == word.lower():
                    print ("detectada moneda en twit")
                    problemInstance = twit.split()
                    problemFeatures = extract_features(problemInstance)
                    tal = classifier.classify(problemFeatures)
                    Moneda = i
                    #print (Moneda, positiu)
                    positiu = "nanan"
                
                    if tal == "positive":
                        print ("positiu")
                        positiu = 1
                    
                    elif tal=="negative":
                        positiu = 0
                        print ("negatiu")
                    postt(Moneda, positiu)
                
    def on_error(self,status_code):
        print("Error",status_code)

   


consumer_key = "kT4NSSFe6H3dx5i9ukra52l4w"
consumer_secret = "ikc4HtNVtfp5efaEfQaVXSVipYXeYn6XTqbGwprZu8gq7GU2bN"
access_token = "1358366959012876289-HRArEh1diSxAjmxKzN9kYhOWlXMqgr"
access_token_secret = "may7rB29a3vPpo1hEPhnegO39DFhcklEAxc6ja1K1oPvy"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth, wait_on_rate_limit_notify=True, wait_on_rate_limit=True)

stream = TweetsListener()
streamingApi= tweepy.Stream(auth=api.auth, listener=stream)
#follow ens diu a qui esta escoltant l'stream tweet
#track ens diu una llista del que passa
streamingApi.filter(
    follow=["2307220706",  "797718721989066752"]   
    )
# Out:
# final: ['300 token', '365Coin', '404Coin', '433 Token', 'SixEleven', '808', 'Octocoin', 'EliteCoin', '2015 coin', 'Arcade City', 'ClubCoin', '007 coin', '0chain', '0x', '0xBitcoin', '16BitCoin', '1717 Masonic Commemorative Token', '1Credit', '1World', '23 Skidoo', '2Acoin', '2BACCO Coin', '2GiveCoin', '2TF', '32Bitcoin', '3DChain', '3DES', '8 Circuit Studios', '8BIT Coin', 'A-Token', 'AAA Reserve Currency', 'AB-CHAIN', 'AB-Chain', 'ABCC Token', 'AC3', 'ACA Token', 'ACT', 'ACoin', 'AEN', 'AEON', 'AERGO', 'AGATE', 'AI Crypto', 'AI Doctor', 'AIChain Token', 'AICoin', 'AIOT Token', 'AITrading', 'AIX', 'ALAX', 'ALISmedia', 'ALTcoin', 'AMBT Token', 'AMIS', 'AMLT', 'AMO Coin', 'ANON', 'ANTS Reloaded', 'APIS', 'APRES', 'AQwire', 'ARBITRAGE', 'ARENON', 'ARK', 'ARNA Panacea', 'ARROUND', 'ASG', 'ASQ Protocol', 'ATB coin', 'ATC Coin', 'ATFS Project', 'ATLANT', 'ATMChain', 'AU-Coin', 'AWAX', 'AXRON', 'AXS', 'Abele', 'Abjcoin', 'Absolute Coin', 'Accelerator Network', 'Accolade', 'AcesCoin', 'AcesCoin', 'Achain', 'AchieveCoin', 'AcidCoin', 'Acorn Collective', 'Actinium', 'Action Coin', 'Acumen', 'Acute Angle Cloud', 'AdCoin', 'AdEx', 'AdToken', 'Adab Solutions', 'Adamant', 'Adbank', 'Adelphoi', 'Adhive', 'Aditus', 'Adshares', 'AdvancedInternetBlock', 'Adzcoin', 'Aegis', 'Aenco', 'Aerium', 'Aero Coin', 'AeroMe', 'Aeron', 'Aerum', 'Aeryus', 'Aeternity', 'Aeternum', 'AfterEther', 'AgaveCoin', 'AgentMile', 'Agoras Token', 'Agrello Delta', 'Ahoolee', 'AiBB', 'AidCoin', 'Aiden', 'Aidos Kuneen', 'Aigang', 'Aimedis', 'Aion', 'AirPod', 'AirSwap', 'AirToken', 'Aircraft', 'Akroma', 'Alcedo', 'Alexandrite', 'Algo.Land', 'Algory', 'Alibabacoin', 'AlienCoin', 'All Sports Coin', 'AllForOneBusiness', 'Allsafe', 'AlpaCoin', 'Alpenschillling', 'AlphaCoin', 'AlphaX', 'Alphacat', 'Alphacon', 'Alprockz', 'Alqo', 'AltCommunity Coin', 'AltoCar', 'Alux Bank', 'AmaStar', 'AmberCoin', 'Ambrosus', 'AmericanCoin', 'Amero', 'Ammo Rewards', 'Amon', 'Amos', 'Amoveo', 'Amsterdam Coin', 'Amygws', 'Anacrypt', 'AnalCoin', 'Anarchists Prime', 'AndromedaCoin', 'Angel Token', 'Animation Vision Cash', 'Animecoin', 'Ankorus Token', 'Ankr Network', 'Anoncoin', 'Anryze', 'Anti Bitcoin', 'AntiHACK.me', 'AntiLitecoin', 'Apex Token', 'ApexCoin', 'Aphelion', 'Apollo Currency', 'ApolloX', 'Apollon', 'AppCoins', 'Aptcoin', 'Apx', 'Aquachain', 'AquariusCoin', 'Ar.cash', 'ArQmA', 'Arab League Coin', 'Aragon', 'Araw', 'Arbi', 'Arbit Coin', 'ArbitrageCT', 'ArcBlock', 'ArcadierX', 'ArchCoin', 'ArcticCoin', 'Ardor', 'Arena', 'Argentum', 'Argoneum', 'ArgusCoin', 'AriCoin', 'Arionum', 'ArkDAO', 'Armory Coin', 'ArpaCoin', 'ArtByte', 'ArtPro', 'Artcoin', 'Artemine', 'ArtexCoin', 'ArubaCoin', 'Ascension Coin', 'Asch', 'Asia Coin', 'Asiadigicoin', 'Aston', 'Astral', 'Astronaut', 'Atheios', 'Athero', 'Atmos', 'Atomic Coin', 'Atomic Wallet Coin', 'Atonomi', 'Attrace', 'Auctus', 'AudioCoin', 'Augur', 'Aukcecoin', 'Aureus', 'Aurora', 'Aurora', 'Aurora Coin', 'Aurum', 'Aussie Digital', 'Authoreon', 'Authorship', 'Authpaper', 'AutoBay', 'AutoBlock', 'Autonio', 'Autoria', 'Autumncoin', 'Auxilium', 'Avalon', 'Avatar Coin', 'AventCoin', 'Averopay', 'Avesta', 'AvonCoin', 'Aworker', 'Axiom Coin', 'Axys', 'Azart', 'Azbit', 'Azultec', 'B21', 'B2BX', 'B3 Coin', 'B3Coin', 'BABB', 'BAM', 'BANCA', 'BANKEX', 'BBNCOIN', 'BCV Blue Chip', 'BEAT Token', 'BEER Coin', 'BERNcash', 'BEX token', 'BF Token', 'BFEX', 'BHPCash', 'BITTO', 'BLOCKv', 'BMChain', 'BOONSCoin', 'BOOSTO', 'BOScoin', 'BQCoin', 'BQT', 'BRAVO Pay', 'BROTHER', 'BTC Lite', 'BTCMoon', 'BTU Protocol', 'BaaSid', 'Babes and Nerds', 'Balkancoin', 'BananaBits', 'Bancor Network Token', 'Bancryp', 'BankCoin', 'Bankera', 'BannerCoin', 'Banyan Network', 'BaseballCardCoin', 'BashCoin', 'Basic Attention Token', 'Basis', 'Bata', 'BattleCoin', 'BattleStake', 'BeachCoin', 'Beam', 'BeanCash', 'BeardDollars', 'Beats', 'BeatzCoin', 'Beauty Chain', 'BeaverCoin', 'Beaxy', 'Bee Token', 'Befund', 'Bela', 'BelugaPay', 'Benchmark', 'Benjacoin', 'BenjiRolls', 'BestChain', 'BetKings', ...
# Working
